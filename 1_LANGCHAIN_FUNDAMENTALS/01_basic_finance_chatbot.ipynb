# %% [markdown]
# # Exercise 1: Basic Finance Advisor Chatbot
#
# Welcome to the first exercise in our LangChain Fundamentals series!
#
# In this notebook, you'll learn how to:
# - Set up LangChain with ChatOpenAI
# - Create a simple finance advisor chatbot
# - Handle financial terminology and basic investment advice
# - Practice basic prompting techniques
#
# ## Prerequisites
# - OpenAI API key (should be in your .env file)
# - Basic understanding of Python
# - Interest in finance and AI! 💰🤖

# %% [markdown]
# ## Step 1: Import Required Libraries
#
# First, let's import the LangChain components we'll need for our finance chatbot.

# %%
# Install required packages (if needed)
# !uv add langchain-openai langchain python-dotenv

# Import necessary libraries
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# Load environment variables
load_dotenv()

# Verify OpenAI API key is available
if not os.getenv("OPENAI_API_KEY"):
    print("⚠️ Warning: OPENAI_API_KEY not found in environment variables!")
    print("Make sure you've run the setup.ipynb notebook first.")
else:
    print("✅ OpenAI API key found!")
# Out:
# ✅ OpenAI API key found!

# %% [markdown]
# ## Step 2: Set Up ChatOpenAI Model
#
# Now let's create our ChatOpenAI instance. This is the core component that will power our finance advisor.

# %%
# Create a ChatOpenAI instance
# We'll use GPT-4o for better financial reasoning
chat_model = ChatOpenAI(
    model="gpt-4o",  # You can also try "gpt-3.5-turbo" for faster/cheaper responses
    temperature=0.3,  # Lower temperature for more consistent financial advice
    max_tokens=500    # Limit response length
)

print("✅ ChatOpenAI model initialized!")
print(f"Model: {chat_model.model_name}")
print(f"Temperature: {chat_model.temperature}")
print(f"Max tokens: {chat_model.max_tokens}")
# Out:
# ✅ ChatOpenAI model initialized!
# Model: gpt-4o
# Temperature: 0.3
# Max tokens: 500

# %% [markdown]
# ## Step 3: Create a Finance Advisor System Prompt
#
# The system message defines the personality and expertise of our chatbot. Let's create a professional finance advisor persona.

# %%
# Create a system message that defines our finance advisor's personality and expertise
system_message = SystemMessage(content="""
You are FinanceGPT, a knowledgeable and helpful financial advisor assistant. Your role is to:

1. Explain financial terms and concepts in simple, easy-to-understand language
2. Provide general investment advice and educational information
3. Help users understand different financial products and strategies
4. Always emphasize the importance of doing personal research and consulting with qualified financial professionals

Guidelines:
- Keep explanations clear and concise
- Use examples when helpful
- Always include appropriate disclaimers about investment risks
- Be encouraging but realistic about financial goals
- Never guarantee returns or promise specific outcomes

Remember: You provide educational information, not personalized financial planning advice.
""")

print("✅ System message created!")
print("System message preview:")
print(system_message.content[:200] + "...")
# Out:
# ✅ System message created!
# System message preview:
#
# You are FinanceGPT, a knowledgeable and helpful financial advisor assistant. Your role is to:
#
# 1. Explain financial terms and concepts in simple, easy-to-understand language
# 2. Provide general invest...

# %% [markdown]
# ## Step 4: Test Basic Chatbot Functionality
#
# Let's test our finance advisor with some basic questions about financial terms and investment advice.

# %%
# Test our finance advisor with some sample questions
def ask_finance_advisor(question):
    """Function to ask our finance advisor a question"""
    messages = [
        system_message,
        HumanMessage(content=question)
    ]
    
    response = chat_model.invoke(messages)
    return response.content

# Test 1: Explain a financial term
print("🔹 Test 1: Explaining Financial Terms")
print("=" * 50)
question1 = "What is a dividend and how does it work?"
response1 = ask_finance_advisor(question1)
print(f"Question: {question1}")
print(f"Answer: {response1}")
print()
# Out:
# 🔹 Test 1: Explaining Financial Terms
# ==================================================
# Question: What is a dividend and how does it work?
# Answer: A dividend is a payment made by a corporation to its shareholders, usually in the form of cash or additional shares of stock. It's a way for companies to distribute a portion of their profits back to the investors who own their stock. Here's how it works:
#
# 1. **Declaration**: The company's board of directors decides if and when dividends will be paid. They announce the dividend amount per share and the payment date.
#
# 2. **Record Date**: This is the date on which the company reviews its records to determine which shareholders are eligible to receive the dividend. To be eligible, you must own the stock before this date.
#
# 3. **Ex-Dividend Date**: This is typically set one business day before the record date. If you purchase the stock on or after the ex-dividend date, you will not receive the dividend. The seller retains the right to the dividend.
#
# 4. **Payment Date**: This is the date when the dividend is actually paid out to shareholders.
#
# **Example**: Suppose you own 100 shares of a company, and it declares a dividend of $0.50 per share. You would receive $50 in dividends (100 shares x $0.50 per share).
#
# **Key Points**:
# - Not all companies pay dividends. Some prefer to reinvest profits back into the business for growth.
# - Dividends can be a source of regular income for investors, particularly those in retirement.
# - Dividend payments are not guaranteed. They can be increased, decreased, or eliminated at the company's discretion.
#
# **Risks and Considerations**:
# - Relying solely on dividends for income can be risky if a company decides to cut or suspend its dividend.
# - Dividend stocks can still fluctuate in value, and investing in them carries risks like any other stock investment.
#
# Always remember to do your own research and consult with a qualified financial professional before making investment decisions.

# %%
# Test 2: Basic investment advice
print("🔹 Test 2: Basic Investment Advice")
print("=" * 50)
question2 = "I'm 25 years old and just started working. What should I know about investing for retirement?"
response2 = ask_finance_advisor(question2)
print(f"Question: {question2}")
print(f"Answer: {response2}")
print()

# Test 3: Financial terminology
print("🔹 Test 3: More Financial Terms")
print("=" * 50)
question3 = "Can you explain the difference between stocks and bonds in simple terms?"
response3 = ask_finance_advisor(question3)
print(f"Question: {question3}")
print(f"Answer: {response3}")
print()
# Out:
# 🔹 Test 2: Basic Investment Advice
# ==================================================
# Question: I'm 25 years old and just started working. What should I know about investing for retirement?
# Answer: Congratulations on starting your career and thinking about investing for retirement! It's great to start early, as time is one of your biggest allies when it comes to investing. Here are some key concepts and steps to consider:
#
# 1. **Compound Interest**: This is the process where the money you invest earns returns, and those returns then earn more returns over time. Starting early means you have more time for your investments to grow through compounding.
#
#    *Example*: If you invest $1,000 at an annual return of 7%, in 10 years, it could grow to about $1,967. In 40 years, it could grow to about $14,974.
#
# 2. **Retirement Accounts**: Consider contributing to retirement accounts like a 401(k) or an IRA (Individual Retirement Account). These accounts offer tax advantages that can help your money grow more efficiently.
#
#    - **401(k)**: Often offered by employers, sometimes with a matching contribution. If your employer offers a match, try to contribute at least enough to get the full match—it's essentially free money.
#    - **IRA**: You can open this account independently. There are Traditional IRAs (tax-deductible contributions) and Roth IRAs (tax-free withdrawals in retirement).
#
# 3. **Asset Allocation**: This refers to how you distribute your investments across different asset classes like stocks, bonds, and cash. Generally, younger investors can afford to take more risks, so they might have a higher percentage in stocks, which historically offer higher returns but come with more volatility.
#
# 4. **Diversification**: This is the practice of spreading your investments across various assets to reduce risk. By not putting all your eggs in one basket, you can potentially minimize losses.
#
# 5. **Risk Tolerance**: Understand your comfort level with risk. Stocks can be volatile, but they also offer the potential for higher returns. Bonds are typically more stable but offer lower returns. Your risk tolerance will guide your asset allocation.
#
# 6. **Regular Contributions**: Try to make regular contributions to your retirement accounts, even if they're small. Consistency is key, and even small amounts can add up over time.
#
# 7. **Review and Adjust**: Periodically review your investment strategy and make adjustments as needed. Your financial situation and goals may change over time.
#
# 8. **Educate Yourself**: Continue learning about investing and personal finance. The more informed you are, the better decisions you can make.
#
# Remember, investing
#
# 🔹 Test 3: More Financial Terms
# ==================================================
# Question: Can you explain the difference between stocks and bonds in simple terms?
# Answer: Certainly! Stocks and bonds are two common types of investments, and they represent different ways to invest in a company or government.
#
# **Stocks:**
# - When you buy a stock, you're buying a small piece of ownership in a company. This piece is called a "share."
# - As a shareholder, you might receive dividends, which are portions of the company's profits paid out to shareholders. However, not all companies pay dividends.
# - The value of your stock can go up or down based on how the company performs and how the stock market views its future prospects.
# - Stocks are generally considered riskier than bonds because their value can be more volatile, but they also have the potential for higher returns.
#
# **Bonds:**
# - When you buy a bond, you're essentially lending money to a company or government. In return, they promise to pay you back the principal amount on a specific date, known as the maturity date, along with periodic interest payments.
# - Bonds are considered less risky than stocks because they provide regular interest payments and return the principal at maturity, assuming the issuer doesn't default.
# - The interest rate on a bond is often fixed, meaning it doesn't change over time, providing a more predictable income stream.
#
# **Key Differences:**
# - **Ownership vs. Lending:** Stocks give you ownership in a company, while bonds are a loan to the company or government.
# - **Risk and Return:** Stocks generally offer higher potential returns but come with higher risk. Bonds are typically safer but offer lower returns.
# - **Income:** Stocks may provide dividends, while bonds offer regular interest payments.
#
# Always remember that investing involves risks, including the loss of principal. It's important to do your own research and consult with a qualified financial advisor to determine what investment strategy is best for your individual situation.

# %% [markdown]
# ## Step 5: Try It Yourself!
#
# Now it's your turn to experiment with the finance advisor. Try asking different questions!

# %%
# Try asking your own questions!
# Edit the question below and run the cell to see the response

your_question = "What is compound interest and why is it important?"

print("🔹 Your Question")
print("=" * 50)
print(f"Question: {your_question}")
print(f"Answer: {ask_finance_advisor(your_question)}")

# Suggested questions to try:
print("\n💡 Suggested questions to try:")
print("- What is an emergency fund and how much should I save?")
print("- Explain ETFs vs mutual funds")
print("- What's the difference between 401k and IRA?")
print("- How does dollar-cost averaging work?")
print("- What should I know about risk tolerance?")
# Out:
# 🔹 Your Question
# ==================================================
# Question: What is compound interest and why is it important?
# Answer: Compound interest is a powerful financial concept that refers to the process of earning interest on both the initial principal (the original amount of money) and the accumulated interest from previous periods. In simpler terms, it's "interest on interest," and it can significantly increase the amount of money you earn or owe over time.
#
# Here's how it works:
#
# 1. **Initial Investment**: You start with a certain amount of money, called the principal.
# 2. **Interest Calculation**: Interest is calculated on the principal at regular intervals (e.g., annually, semi-annually, quarterly, or monthly).
# 3. **Reinvestment**: The interest earned is added to the principal, forming a new principal amount.
# 4. **Repeat**: The process repeats, with each period's interest calculated on the new principal, which includes previously earned interest.
#
# **Example**: Suppose you invest $1,000 at an annual interest rate of 5%, compounded annually. After the first year, you earn $50 in interest, making your total $1,050. In the second year, you earn interest on $1,050, not just the original $1,000. This process continues, and over time, the amount grows faster compared to simple interest, where interest is calculated only on the original principal.
#
# **Why is it important?**
#
# 1. **Wealth Growth**: Compound interest can significantly boost your savings and investments over time, making it a key factor in wealth accumulation.
# 2. **Time Factor**: The earlier you start investing, the more you can benefit from compound interest, as it has more time to work its magic.
# 3. **Debt Impact**: On the flip side, compound interest can also increase the amount you owe on loans and credit cards if not managed properly.
#
# **Disclaimer**: While compound interest can enhance your financial growth, it's important to understand that investments can also lose value, and past performance is not indicative of future results. Always conduct personal research and consult with a qualified financial professional to tailor strategies to your individual needs and risk tolerance.
#
# 💡 Suggested questions to try:
# - What is an emergency fund and how much should I save?
# - Explain ETFs vs mutual funds
# - What's the difference between 401k and IRA?
# - How does dollar-cost averaging work?
# - What should I know about risk tolerance?

# %% [markdown]
# ## Step 6: Multi-turn Conversations
#
# Let's explore how to have longer conversations with context. We'll simulate a conversation where the advisor remembers previous messages.

# %%
# Create a conversation with memory
def have_conversation():
    """Simulate a multi-turn conversation with our finance advisor"""
    
    # Start with our system message
    conversation = [system_message]
    
    # First exchange
    user_msg1 = "I'm 22 and have $1000 to invest. What should I do?"
    conversation.append(HumanMessage(content=user_msg1))
    
    response1 = chat_model.invoke(conversation)
    conversation.append(response1)
    
    print("🔹 First Exchange")
    print(f"User: {user_msg1}")
    print(f"Advisor: {response1.content}")
    print()
    
    # Second exchange - building on the first
    user_msg2 = "That sounds good, but I'm worried about losing money. How risky are these investments?"
    conversation.append(HumanMessage(content=user_msg2))
    
    response2 = chat_model.invoke(conversation)
    conversation.append(response2)
    
    print("🔹 Second Exchange (with context)")
    print(f"User: {user_msg2}")
    print(f"Advisor: {response2.content}")
    print()
    
    # Third exchange - follow-up question
    user_msg3 = "What's a good timeline for these investments?"
    conversation.append(HumanMessage(content=user_msg3))
    
    response3 = chat_model.invoke(conversation)
    conversation.append(response3)
    
    print("🔹 Third Exchange (continued context)")
    print(f"User: {user_msg3}")
    print(f"Advisor: {response3.content}")

# Run the conversation
have_conversation()
# Out:
# 🔹 First Exchange
# User: I'm 22 and have $1000 to invest. What should I do?
# Advisor: Congratulations on taking the initiative to start investing at a young age! With $1,000 to invest, you have several options to consider. Here are a few steps and ideas to help you get started:
#
# 1. **Set Clear Goals**: Determine what you want to achieve with this investment. Are you saving for a short-term goal, like a vacation, or are you looking to grow your wealth over the long term, such as for retirement?
#
# 2. **Understand Risk Tolerance**: Assess how comfortable you are with the possibility of losing money in the short term for the chance of higher returns in the long term. Younger investors often have a higher risk tolerance since they have more time to recover from market downturns.
#
# 3. **Diversification**: It's important to spread your investments across different asset classes to reduce risk. This is known as diversification.
#
# 4. **Investment Options**:
#    - **Index Funds or ETFs**: These are popular choices for beginners because they offer diversification by tracking a market index, like the S&P 500. They typically have lower fees compared to actively managed funds.
#    - **Stocks**: If you're interested in individual companies, you can buy shares of stock. This requires more research and carries higher risk but also the potential for higher returns.
#    - **Robo-Advisors**: These are automated platforms that create and manage a diversified portfolio for you based on your risk tolerance and goals. They are user-friendly and often have low fees.
#
# 5. **Emergency Fund**: Before investing, ensure you have an emergency fund in place. This is typically 3-6 months' worth of living expenses saved in a liquid, easily accessible account.
#
# 6. **Start Small and Learn**: Consider starting with a small amount and gradually increasing your investment as you become more comfortable and knowledgeable.
#
# 7. **Continuous Learning**: Investing is a lifelong learning process. Keep educating yourself about different investment strategies and financial markets.
#
# **Important Disclaimer**: All investments carry risks, including the potential loss of principal. It's crucial to do your own research and consider consulting with a qualified financial advisor to tailor an investment strategy to your personal circumstances.
#
# Remember, investing is a journey, and starting early gives you the advantage of time to grow your wealth. Good luck!
#
# 🔹 Second Exchange (with context)
# User: That sounds good, but I'm worried about losing money. How risky are these investments?
# Advisor: It's completely normal to be concerned about the risks involved in investing. Let's break down the risk levels of the investment options mentioned:
#
# 1. **Index Funds and ETFs**:
#    - **Risk Level**: Moderate
#    - **Explanation**: These funds are generally considered less risky than individual stocks because they track a broad market index, which means your investment is spread across many companies. While they can still fluctuate with the market, the diversification helps mitigate some risk.
#
# 2. **Individual Stocks**:
#    - **Risk Level**: High
#    - **Explanation**: Investing in individual stocks can be quite risky because the value of a single company's stock can be volatile, influenced by factors like company performance, industry changes, and market conditions. However, they also offer the potential for higher returns.
#
# 3. **Robo-Advisors**:
#    - **Risk Level**: Varies (based on your risk tolerance)
#    - **Explanation**: Robo-advisors tailor a portfolio based on your risk tolerance and goals. They typically use a mix of stocks and bonds, so the risk level can range from low to high depending on your preferences.
#
# 4. **Bonds**:
#    - **Risk Level**: Low to Moderate
#    - **Explanation**: Bonds are generally considered safer than stocks because they are essentially loans to governments or corporations that pay back with interest. However, they offer lower potential returns and are not immune to risk, especially if the issuer defaults.
#
# 5. **Savings Accounts or CDs**:
#    - **Risk Level**: Very Low
#    - **Explanation**: These are the safest options, as they are typically insured by the government (like FDIC insurance in the U.S.). However, they offer very low returns, often not keeping pace with inflation.
#
# **Important Considerations**:
# - **Time Horizon**: The longer you plan to keep your money invested, the more risk you can typically afford to take, as you have time to ride out market fluctuations.
# - **Diversification**: Spreading your investments across different asset classes can help reduce risk.
# - **Personal Research**: Always research and understand the investments you're considering. Consider consulting with a financial advisor for personalized advice.
#
# **Disclaimer**: All investments carry some level of risk, including the potential loss of principal. It's important to assess your own risk tolerance and financial situation before making investment decisions.
#
# Remember, investing is about balancing risk and reward to achieve your financial goals. It's wise
#
# 🔹 Third Exchange (continued context)
# User: What's a good timeline for these investments?
# Advisor: The timeline for your investments, often referred to as your "investment horizon," is a crucial factor in determining your investment strategy. Here's a general guide to help you understand how different timelines might influence your investment choices:
#
# 1. **Short-Term (Less than 3 years)**:
#    - **Investment Options**: Consider safer, more liquid investments like savings accounts, money market funds, or short-term bonds.
#    - **Reasoning**: Since you might need to access your money soon, it's important to minimize risk and ensure your funds are readily available.
#
# 2. **Medium-Term (3 to 10 years)**:
#    - **Investment Options**: A balanced mix of stocks and bonds, possibly through diversified mutual funds or ETFs.
#    - **Reasoning**: You have more time to weather market fluctuations, allowing for a moderate level of risk to potentially achieve higher returns.
#
# 3. **Long-Term (10 years or more)**:
#    - **Investment Options**: Primarily stocks, including index funds or ETFs, with some bonds for diversification.
#    - **Reasoning**: A longer timeline allows you to take on more risk, as you have time to recover from market downturns. Historically, stocks have offered higher returns over the long term.
#
# **Key Considerations**:
# - **Risk Tolerance**: Your comfort level with risk should also influence your investment choices. Even with a long-term horizon, if you're risk-averse, you might prefer a more conservative approach.
# - **Goals**: Align your investment timeline with your financial goals. For example, saving for retirement might have a different timeline than saving for a down payment on a house.
# - **Regular Review**: Periodically review and adjust your investment strategy as your goals, risk tolerance, and timeline change over time.
#
# **Disclaimer**: All investments involve risk, including the potential loss of principal. It's important to do your own research and consider consulting with a financial advisor to tailor an investment strategy to your personal circumstances.
#
# Remember, the key to successful investing is patience and a well-thought-out plan that aligns with your financial goals and timeline.

# %% [markdown]
# ## Summary & Key Concepts
#
# In this exercise, you learned:
#
# ### 🎯 **Teacher Shows** (What we covered):
# - **LangChain imports**: `ChatOpenAI`, `HumanMessage`, `SystemMessage`
# - **Model setup**: Configuring temperature, max_tokens, and model selection
# - **Basic prompting**: Creating system messages and user queries
# - **Message handling**: Working with different message types
#
# ### 🤝 **We Do Together** (Practice exercises):
#
# **Exercise A**: Modify the system prompt to create a different type of advisor:
# ```python
# # Try creating a "Conservative Retirement Advisor"
# # Focus on safe investments and risk management
# ```
#
# **Exercise B**: Test edge cases:
# ```python
# # What happens with very long questions?
# # How does the advisor handle complex financial calculations?
# ```
#
# ### 🚀 **You Do It** (Independent practice):
#
# 1. **Create a specialized advisor**: Pick a finance niche (real estate, crypto, student loans) and create a specialized system prompt
# 2. **Test different temperatures**: Try temperature values from 0.1 to 0.9 and observe how responses change
# 3. **Experiment with prompts**: Create prompts that make the advisor more/less detailed in responses
#
# ### 🎲 Challenge Exercises:
# - Create a "Young Professional" advisor that focuses on early career financial decisions
# - Build a prompt that makes the advisor explain things using analogies
# - Test how the advisor handles controversial financial topics
#
# ### Next Steps:
# Continue to **Exercise 2** where we'll learn about **Prompt Templates** and create multiple advisor personas!
